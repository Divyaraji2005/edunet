# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyaraji2005/edunet/blob/main/requirements_solar_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# streamlit
# numpy
# joblib
# scikit-learn
